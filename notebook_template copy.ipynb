# %% [markdown]
# # Lab Title
#
# > A paragraph or two explaining the lab. What question will students explore in the lab? What skills will they learn along the way? Why does it matter?
#
# In this lab you'll investigate `X`. You'll learn `Y` skill along the way.
#
# ---
#
# **Chemistry Learning Objectives:**
# > Choosing chemistry learning objectives is easy. it's more or less just, "what are the four sections of the lab?"
# > PIB is an example of what I find ideal for this.
#
# - C#.1: for Part 1 (understand textbook content from a different angle)
# - C#.2: for Part 2 (understand textbook content from a different angle)
# - C#.3: for Part 3 (connect to a chemistry application)
# - C#.4: for Part 4 (bringing it all together / overarching idea) (ex. comparing models)
#
# **Programming Learning Objectives:**
# > These are a little harder, but in general two new syntax/library techniques and connect to a mental model. Gives us the juicy transfer.
#
# > specific things to hit for mental models-
# > - abstraction (seeing the purpose of blocks of code, instead of line-for-line),
# > - decomposition (breaking down a problem),
# > - metacognition (thinking about how you approach a problem, planning and keeping track of progress)
#
# - P#.1: A mental model (functions as physical models, for example)
# - P#.2: Syntax or a library
# - P#.3: Syntax or a library
#
# ---
#
# **Table of Contents**
# - [Warmup - math/code topic and philosophy of it](#warmup) `NN points`
# - [Part 1 - textbook content](#part1) `NN points`
# - [Part 2 - textbook content](#part2) `NN points`
# - [Part 3 - chemical application](#part3) `NN points`
# - [Part 4 - bringing it all together](#part4) `NN points`
# - [Reflection](#reflection) `10 points`
#
# `Total: NNN points`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# import helper functions etc in the cell they're used 
# in to avoid confusion about where they came from

# %% [markdown]
# <a id="warmup"></a>
#
# ## Warmup - Title
#
# > **The intro paragraph**
#
# > Briefly introduce what coding technique we're teaching them and what it's useful for.
#
# > Touch a bit on the mental model here if you can too.
#
# > in my opinion, best to keep this short, lest their eyes glaze over. A small amount of information, read, is better than the library of alexandria glazed over
#
# A commonly useful technique in programming is...

# %% [markdown]
# ### Coding Activity (Warmup)
# `NN points`
#
# - P#.1: Relevant learning objective
#
# `some text explaining what they will do to practice the coding technique, outline following parts`

# %% [markdown]
# #### W.A - Subtitle
#
# > I prefer to use the worked example -> your turn pattern for the warmup.
#
# > Don't ask students to do something they haven't seen, or at least link to documentation if you do.
#
# `Context sentence explaining what this task does and why it matters.`
#
# **Your task:**
# 1. First step
# 2. Second step

# %%
# --- Worked example: description ---
# [code that demonstrates the technique]

result = some_function(input)   # YOUR COMMENT HERE
print(result)                   # YOUR COMMENT HERE

# %%
# Your turn: [slightly different version of the above]
# YOUR CODE HERE

# %% [markdown]
# #### W.B - Subtitle 2
#
# > I prefer to use the worked example -> your turn pattern for the warmup.
#
# > Don't ask students to do something they haven't seen, or at least link to documentation if you do.
#
# `Context sentence explaining what this task does and why it matters.`
#
# **Your task:**
# 1. First step
# 2. Second step

# %%
# --- Worked example: description ---
# [code that demonstrates the technique]

result = some_function(input)   # YOUR COMMENT HERE
print(result)                   # YOUR COMMENT HERE

# %%
# Your turn: [slightly different version of the above]
# YOUR CODE HERE

# %% [markdown]
# #### W.C - Subtitle 3
#
# > I prefer to use the worked example -> your turn pattern for the warmup.
#
# > Don't ask students to do something they haven't seen, or at least link to documentation if you do.
#
# `Context sentence explaining what this task does and why it matters.`
#
# **Your task:**
# 1. First step
# 2. Second step

# %%
# --- Worked example: description ---
# [code that demonstrates the technique]

result = some_function(input)   # YOUR COMMENT HERE
print(result)                   # YOUR COMMENT HERE

# %%
# Your turn: [slightly different version of the above]
# YOUR CODE HERE

# %% [markdown]
# ### Question (Warmup)
# `NN points`
#
# - P#.1: Relevant programming objective
# - C#.1: Relevant chemistry objective
#
# > SRQs should bridge the output of the coding activity and the learning objective.
#
# > SRQ sets should include at least one lower-order (remember / understand / apply) and at least one higher-order question (analyze / evaluate / create).
#
#
# a) [Lower-order] Describe/identify/explain something directly visible in the output.
#
# b) [Higher-order] Analyze, compare, or predict something based on what you observed.
#
# > (probably don't have more than ~3 SRQs per part.)
#
# ---

# %% [markdown]
# *Your answer here (`double click me!`):*

# %% [markdown]
# <br></br>

# %% [markdown]
# <a id="part1"></a>
#
# ## Part 1 - Title
#
# > At a high level, introduce whatever background the students need to understand what this part means.
#
# > These are hard to write. In my opinion they should be concise as possible. If you have a lot of good content, break it up among the different coding activity subparts to avoid overwhelming students with a big block of text.
#
# Introductory prose explaining the relevant concept and the question being asked.
# Equations go here if needed: $E = mc^2$, or display:
# $$
# E = mc^2
# $$
#
# ---

# %% [markdown]
# ### Coding Activity 1
# `NN points`
#
# > **📝 Guidance — Part 1 dominant pattern: Worked example → your turn.**
# > All three sub-parts use this pattern at increasing difficulty.
# > A: identical repeat of worked example on different data. B: slight variation requiring independent choice. C: extension combining A and B.
#
# - C#.1: Relevant chemistry objective
# - P#.1: Relevant programming objective

# %% [markdown]
# #### Part A — Subtitle
#
# > **📝 Guidance — Part A (all parts): Worked example with comment stubs → your turn.**
# > This is the required pattern for Part A in *every* section of the notebook.
# > Show how to do the technique with `# YOUR COMMENT HERE` stubs on key lines.
# > Then ask students to do it once more for something slightly different — same structure, different input.
# > Do NOT skip this step even if it seems too easy. First encounters always need a worked example.
#
# Context sentence explaining what they are about to do.
#
# **Your task:**
# 1. Read the worked example and add a comment to each stub line.
# 2. Repeat the same steps for [slightly different input/dataset/parameter].

# %%
# --- Worked example: [description] ---
# Subgoal: [first subgoal]
result_example = some_function(example_input)    # YOUR COMMENT HERE
processed = result_example * scale_factor        # YOUR COMMENT HERE

# Subgoal: [second subgoal]
plt.plot(x_example, processed)                   # YOUR COMMENT HERE
plt.xlabel('x label (units)')                    # YOUR COMMENT HERE
plt.ylabel('y label (units)')                    # YOUR COMMENT HERE
plt.title('Example title')                       # YOUR COMMENT HERE
plt.show()

# %%
# Your turn: repeat for [different input]
# Subgoal: [first subgoal]

# Subgoal: [second subgoal]

# YOUR CODE HERE

# %% [markdown]
# #### Part B — Subtitle
#
# > **📝 Guidance — Part B (Part 1): Worked example → your turn, with more independence.**
# > No worked example provided here. Students apply the same technique to a variation that requires a small new choice or combination. Ideal for the second task after A.
# > If the jump from A to B feels too big, break it into a smaller intermediate step or add a hint.
#
# Context sentence.
#
# **Your task:**
# 1. [Step that requires applying the skill from A in a new context]
# 2. [Optional: additional step]

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Part C — Subtitle
#
# > **📝 Guidance — Part C (Part 1): Extension.**
# > This should be the most challenging sub-part. It can require combining what students did in A and B, or add one new concept that builds directly on both.
# > Still keep it in the "worked example → your turn" family — provide scaffold comments (subgoal labels) but no complete worked code.
# > Max 3–4 sub-parts per coding activity. If it needs more, split into a new coding activity.
#
# Context sentence.
#
# **Your task:**
# - [Task that synthesizes or extends A and B]

# %%
# Subgoal: [first step]

# Subgoal: [second step]

# YOUR CODE HERE

# %% [markdown]
# ### Question 1
# `NN points`
#
# > **📝 Guidance — SRQs:** 2–3 questions. At least one lower-order (a) and one higher-order (b or c).
# > The questions should guide students to *notice* and *interpret* the result of the coding activity — they should not be answerable without running the code first.
# > A good higher-order question asks students to connect the result to a broader schema: "What does this tell you about [concept]?"
# > Avoid questions that merely point at the plot ("What is the value of X?") — push toward interpretation.
#
# - C#.1: Relevant learning objective
#
# a) [Lower-order: Bloom's Remember/Understand/Apply] Describe or identify something directly visible in your output.
#
# b) [Higher-order: Bloom's Analyze/Evaluate] Interpret, compare, or explain what your result reveals about the underlying concept.
#
# c) [Optional: Bloom's Evaluate/Create] Connect the result to a broader schema or predict what would happen if a parameter changed.
#
# ---

# %% [markdown]
# *Your answer here (`double click me!`):*

# %% [markdown]
# <br></br>

# %% [markdown]
# <a id="part2"></a>
#
# ## Part 2 — Title
#
# > **📝 Guidance — Part 2 dominant pattern: Comment a worked example.**
# > Use this pattern when students need to *understand* a more complex piece of code before they can use or modify it.
# > Part A (worked example → your turn) builds the baseline. Part B provides complete, working code students must explain line by line. Part C asks them to apply that understanding by writing something new.
#
# Introductory prose. Frame the new question. Equations if needed.
#
# ---

# %% [markdown]
# ### Coding Activity 2
# `NN points`
#
# - C#.2: Relevant chemistry objective
# - P#.2: Relevant programming objective

# %% [markdown]
# #### Part A — Subtitle
#
# > **📝 Guidance — Part A (all parts): Worked example with comment stubs → your turn.**
# > Same as Part 1A. Show the technique with comment stubs on non-obvious lines, then ask students to do it for a slightly different case.
#
# Context sentence.
#
# **Your task:**
# 1. Read the worked example and fill in each comment stub.
# 2. Repeat for [slightly different version].

# %%
# --- Worked example: [description] ---
result = some_operation(input_a)    # YOUR COMMENT HERE
output = transform(result)          # YOUR COMMENT HERE
print(output)

# %%
# Your turn: repeat for [different input]
# YOUR CODE HERE

# %% [markdown]
# #### Part B — Comment a Worked Example
#
# > **📝 Guidance — Part B (Part 2): Comment a worked example.**
# > Provide a complete, working block of code that is more complex than what students have seen so far — perhaps a loop, a multi-step calculation, or a function definition.
# > Ask students to add comments explaining *what* each part does and *why*.
# > This is most useful for reinforcing understanding before a "your turn" that requires modifying the same code.
# > Tip: combine with Part C by then asking students to modify or extend the code they just commented.
#
# The cell below performs [describe what it does]. Read it carefully and add a comment to each line explaining what it does and why.
#
# **Your task:**
# 1. Read the code in the cell below without running it.
# 2. Add a comment to each `# YOUR COMMENT HERE` stub explaining what that line does and why.
# 3. Run the cell and verify your comments are correct.

# %%
# --- Complete example to comment ---
def example_function(data, parameter):
    processed = data * parameter       # YOUR COMMENT HERE
    result = np.sum(processed)         # YOUR COMMENT HERE
    return result                      # YOUR COMMENT HERE

values = np.linspace(0, 10, 100)      # YOUR COMMENT HERE
output = example_function(values, 2)  # YOUR COMMENT HERE
print(f'Result: {output:.3f}')        # YOUR COMMENT HERE

# %% [markdown]
# #### Part C — Apply Your Understanding
#
# > **📝 Guidance — Part C (Part 2): Your turn, informed by B.**
# > Ask students to *modify* or *extend* the code they just commented. Because they have just read and explained it, the cognitive load of the extension step is lower.
# > This closes the "comment a worked example → your turn" loop.
#
# Now that you understand what `example_function` does, modify it to [describe the variation].
#
# **Your task:**
# 1. Copy the function from Part B and modify it to [do something slightly different]
# 2. Apply your modified function to [new input] and plot or print the result.

# %%
# Modify example_function so that it [description of change]

# YOUR CODE HERE

# %% [markdown]
# ### Question 2
# `NN points`
#
# > **📝 Guidance — SRQs:** 2–3 questions, at least one lower-order and one higher-order.
# > For a "comment a worked example" section, good lower-order questions ask students to describe what a specific piece of code does.
# > Good higher-order questions ask them to reason about *why* the code is structured that way, or what would happen if a part were changed.
#
# - C#.2: Relevant learning objective
#
# a) [Lower-order] Describe in plain English what [specific part of the code] does.
#
# b) [Higher-order] What would change if you altered [parameter / structure of code]? Explain your reasoning.
#
# c) [Optional] Connect this technique to [broader concept or physical interpretation].
#
# ---

# %% [markdown]
# *Your answer here (`double click me!`):*

# %% [markdown]
# <br></br>

# %% [markdown]
# <a id="part3"></a>
#
# ## Part 3 — Title
#
# > **📝 Guidance — Part 3 dominant pattern: Fill-in-the-blank and Target practice.**
# > Use these when students have seen the technique before and just need to apply one specific piece within a larger workflow.
# > Fill-in-the-blank: provide a mostly-complete function or loop with 1–2 key lines missing.
# > Target practice: provide all the surrounding scaffolding (data loading, plotting) so students can focus their cognitive load entirely on the one part you care about teaching.
# > Both patterns are good for reducing extraneous cognitive load on irrelevant parts of the workflow.
#
# Introductory prose. Frame the new question.
#
# ---

# %% [markdown]
# ### Coding Activity 3
# `NN points`
#
# - C#.1: Relevant chemistry objective
# - P#.2: Relevant programming objective

# %% [markdown]
# #### Part A — Subtitle
#
# > **📝 Guidance — Part A (all parts): Worked example with comment stubs → your turn.**
#
# Context sentence.
#
# **Your task:**
# 1. Fill in the comment stubs.
# 2. Repeat the technique for [slightly different case].

# %%
# --- Worked example: [description] ---
result = compute_something(x)    # YOUR COMMENT HERE
plt.plot(x, result, label='example')  # YOUR COMMENT HERE
plt.legend()
plt.show()

# %%
# Your turn: [slightly different case]
# YOUR CODE HERE

# %% [markdown]
# #### Part B — Fill-in-the-Blank
#
# > **📝 Guidance — Part B (Part 3): Fill-in-the-blank.**
# > Provide a mostly-complete function or loop. Leave out exactly the 1–2 lines that implement the concept you want students to focus on.
# > Everything else is given. Students should be able to complete this in a few minutes.
# > Good candidates for the blank: the key formula, a filter condition, a transformation step.
# > Add a comment indicating *what* the missing line should accomplish, not *how* to write it.
#
# The function below is mostly complete. Fill in the missing line(s) to make it work.
#
# **Your task:**
# - Complete the `# YOUR CODE HERE` line(s) inside the function.

# %%
def target_function(x, parameter):
    """
    [Docstring: describe what this function should do]
    Parameters
        x : array-like
        parameter : float
    Returns
        result : array-like
    """
    # YOUR CODE HERE — compute [key formula or transformation]
    # (everything else is done for you)
    result = None  # replace this line
    return result

# Test your function:
x = np.linspace(0, 10, 100)
output = target_function(x, parameter=2.0)
plt.plot(x, output)
plt.xlabel('x')
plt.ylabel('output')
plt.title('[Title]')
plt.show()

# %% [markdown]
# #### Part C — Target Practice
#
# > **📝 Guidance — Part C (Part 3): Target practice.**
# > Provide all data loading, preprocessing, and plotting code. Students only fill in the critical computational step.
# > This is useful when the important concept is buried inside a longer workflow (e.g., a fitting routine, a numerical integration, a matrix operation).
# > Label clearly what is provided and what students must write. Use `# --- Given: ... ---` and `# --- Your task: ... ---` markers.
#
# The code below loads and plots the data for you. Your job is to add the [key computational step] in the marked section.
#
# **Your task:**
# - Fill in the section marked `# --- Your task: ---`

# %%
# --- Given: load and inspect data ---
data = pd.read_csv('data/[filename].csv')
x = data['x_column'].values
y = data['y_column'].values

# --- Your task: [describe the operation] ---
# Hint: [optional hint pointing to a relevant function or approach]
# YOUR CODE HERE

# --- Given: plot results ---
plt.scatter(x, y, label='data', s=10)
# plt.plot(x, your_result, label='[your result]', color='red')
plt.xlabel('[x label (units)]')
plt.ylabel('[y label (units)]')
plt.title('[Title]')
plt.legend()
plt.show()

# %% [markdown]
# ### Question 3
# `NN points`
#
# > **📝 Guidance — SRQs:** 2–3 questions, at least one lower-order and one higher-order.
# > For fill-in-the-blank / target practice sections, good lower-order questions confirm that students understood the step they implemented.
# > Good higher-order questions ask them to reason about what would happen if the key formula or parameter were different — connecting the code to the physics.
#
# - C#.1: Relevant learning objective
#
# a) [Lower-order] What does [the key formula/operation you implemented] represent physically?
#
# b) [Higher-order] How does your output change when [parameter] increases? Does this make physical sense?
#
# c) [Optional higher-order] What limitation of this approach would matter if we applied it to [edge case or real system]?
#
# ---

# %% [markdown]
# *Your answer here (`double click me!`):*

# %% [markdown]
# <br></br>

# %% [markdown]
# <a id="part4"></a>
#
# ## Part 4 — Title
#
# > **📝 Guidance — Part 4 dominant pattern: Translating pseudocode and formulas into functions.**
# > Use these when students have already encountered the technique and you want them to consolidate understanding by implementing it from a description or equation.
# > Translating pseudocode: write out the algorithm as numbered English steps, ask students to turn it into Python.
# > Translating formulas into functions: provide the mathematical expression, ask students to implement it as a Python function.
# > Both are most effective for reinforcing something students have done before — not first encounters.
#
# Introductory prose. Frame the question.
#
# ---

# %% [markdown]
# ### Coding Activity 4
# `NN points`
#
# - C#.2: Relevant chemistry objective
# - P#.1: Relevant programming objective

# %% [markdown]
# #### Part A — Subtitle
#
# > **📝 Guidance — Part A (all parts): Worked example with comment stubs → your turn.**
#
# Context sentence.
#
# **Your task:**
# 1. Add comments to the worked example.
# 2. Repeat for [different input].

# %%
# --- Worked example: [description] ---
step_one = compute_a(input_data)        # YOUR COMMENT HERE
step_two = combine(step_one, constant)  # YOUR COMMENT HERE
print(f'Result: {step_two:.4f}')        # YOUR COMMENT HERE

# %%
# Your turn: [different input]
# YOUR CODE HERE

# %% [markdown]
# #### Part B — Translating Pseudocode
#
# > **📝 Guidance — Part B (Part 4): Translating pseudocode into Python.**
# > List each step of the procedure as a numbered English sentence. Ask students to write the Python that implements each step.
# > This is best for algorithms students have already seen (e.g., a regression procedure, an integration loop) — it reinforces understanding rather than introducing something new.
# > Label each pseudocode step with a comment stub; students fill in the code beneath each one.
#
# Implement the following procedure in Python.
#
# **Algorithm:**
# 1. [Step 1 in plain English, e.g., "Load the dataset and extract columns X and Y"]
# 2. [Step 2, e.g., "Compute the mean of Y"]
# 3. [Step 3, e.g., "For each value x_i, evaluate the model function"]
# 4. [Step 4, e.g., "Plot the results"]
#
# **Your task:** Translate each step into Python.

# %%
# Step 1: [English description]
# YOUR CODE HERE

# Step 2: [English description]
# YOUR CODE HERE

# Step 3: [English description]
# YOUR CODE HERE

# Step 4: [English description]
# YOUR CODE HERE

# %% [markdown]
# #### Part C — Translating a Formula into a Function
#
# > **📝 Guidance — Part C (Part 4): Translating a formula into a function.**
# > Provide the mathematical expression and a docstring stub. Ask students to implement it.
# > This is good for formulas that have appeared in lecture or earlier in the notebook.
# > After writing the function, ask students to apply it to real data — so the result is immediately meaningful.
# > Provide a sanity-check test so students can verify their implementation before applying it.
#
# Implement the formula below as a Python function, then apply it to the data.
#
# $$[	ext{formula}]$$
#
# where [define each symbol and its units].
#
# **Your task:**
# 1. Implement the function `compute_quantity` below.
# 2. Apply it to the provided data and plot the result.
# 3. Run the sanity check and confirm it passes.

# %%
def compute_quantity(x, parameter):
    """
    [Description of what this function computes.]
    Parameters
        x : (units) float or array-like
        parameter : (units) float
    Returns
        result : (units) float or array-like
    """
    # YOUR CODE HERE — implement the formula above
    pass

# Sanity check (run this after writing your function):
# expected = [known value for a simple input]
# computed = compute_quantity([simple input], [parameter])
# print(f'Expected: {expected}, Got: {computed:.4f}')

# Apply to data and plot:
# YOUR CODE HERE

# %% [markdown]
# ### Question 4
# `NN points`
#
# > **📝 Guidance — SRQs:** 2–3 questions, at least one lower-order and one higher-order.
# > For pseudocode / formula-translation sections, a good lower-order question confirms students understand what each variable represents.
# > A good higher-order question asks them to evaluate the model — its assumptions, its limits, or how it compares to an alternative approach.
# > If this is the final coding section, use the SRQ to synthesize the full narrative of the lab.
#
# - C#.2: Relevant learning objective
#
# a) [Lower-order] Define [key variable in the formula] and state its units and physical meaning.
#
# b) [Higher-order] Compare this result to what you found in [earlier part]. What does the agreement (or disagreement) tell you about [the underlying model or concept]?
#
# c) [Higher-order, synthesis] Based on all parts of this lab, evaluate [the core question the lab was designed to answer].
#
# ---

# %% [markdown]
# *Your answer here (`double click me!`):*

# %% [markdown]
# <br></br>

# %% [markdown]
# <a id="reflection"></a>
#
# ## Reflection
# `10 points`
#
# > **📝 Guidance — Reflection:** 3–4 open-ended questions. These should be personal and metacognitive — they are not graded for correctness but for honest engagement.
# > Good reflection questions: ask students to evaluate their own understanding, connect the lab to a broader context (their research, another course, the world), or notice what surprised them.
# > At least one question should be explicitly metacognitive ("what did you find hardest/easiest and why?").
#
# a) [Metacognitive] What part of this lab challenged you the most, and what helped you make progress on it?
#
# b) [Connection to schema] How does the result of this lab fit into the broader framework of [course theme or concept]? Does it change or reinforce how you thought about [concept] before?
#
# c) [Transfer] Describe a real or hypothetical scenario outside this lab where you could apply one of the techniques or ideas from today.
#
# d) [Optional] If you could improve one thing about this lab to make it clearer or more useful, what would it be?

# %% [markdown]
# *Your answer here (`double click me!`):*
