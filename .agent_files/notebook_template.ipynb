# %% [markdown]
# # Lab Title
#
# 1-2 sentence introduction framing the lab's purpose and relevance.
#
# ---
#
# **Chemistry Learning Objectives:**
# - C#.1: Objective in imperative form
# - C#.2: Another objective
#
# **Programming Learning Objectives:**
# - P#.1: Objective in imperative form
# - P#.2: Another objective
#
# ---
#
# **Table of Contents**
# - [Warmup - Title](#warmup) `NN points`
# - [Part 1 - Title](#part1) `NN points`
# - [Part 2 - Title](#part2) `NN points`
# - [Reflection](#reflection) `10 points`
#
# `Total: NNN points`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from module_helper import ...

# %% [markdown]
# <a id="warmup"></a>
#
# ## Warmup - Title
#
# Introductory prose for the warmup section.

# %% [markdown]
# ### Coding Activity (Warmup)
# `NN points`
#
# - P#.1: Relevant learning objective
#
# Brief description of the activity.

# %% [markdown]
# #### W.A - Subtitle
#
# **Your task:**
# 1. First step
# 2. Second step

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Question (Warmup)
# `NN points`
#
# a) Question text
#
# b) Question text
#
# ---

# %% [markdown]
# *Your answer here (`double click me!`):*

# %% [markdown]
# <br></br>

# %% [markdown]
# <a id="part1"></a>
#
# ## Part 1 - Title
#
# Introductory prose explaining the physics/chemistry concepts.
# LaTeX equations go here: $E = mc^2$ or display:
# $$E = mc^2$$
#
# ---

# %% [markdown]
# ### Coding Activity 1
# `NN points`
#
# - C#.1: Relevant chemistry objective
# - P#.1: Relevant programming objective

# %% [markdown]
# #### Part A - Subtitle
#
# Context and explanation.
#
# **Your task:**
# 1. First step
# 2. Second step

# %%
# --- Worked example: description ---
# Code that demonstrates the technique
# Students add comments: # YOUR COMMENT HERE

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Part B - Subtitle
#
# Context and explanation.
#
# **Your task:**
# - Task description

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Question 1
# `NN points`
#
# - C#.1: Relevant learning objective
#
# a) Question text
#
# b) Question text
#
# c) Question text
#
# ---

# %% [markdown]
# *Your answer here (`double click me!`):*

# %% [markdown]
# <br></br>

# %% [markdown]
# <a id="reflection"></a>
#
# ## Reflection
# `10 points`
#
# a) Open-ended reflection question
#
# b) Open-ended reflection question
#
# c) Open-ended reflection question

# %% [markdown]
# *Your answer here (`double click me!`):*
